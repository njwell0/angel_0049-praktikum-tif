# %%
# menyimpan nama
nama = "Archangela Girlani Sekar Sabat"
# menyimpan NIM
nim = "2605060049"
# mentimpan tempat dan tanggal lahir
ttl = "Magelang, 26 Januari 2008"
# menyimpan jenis kelamin
jenis_kelamin = "perempuan"
# menyimpan hobi
hobi = "menyanyi"

# menampilkan biodata
print(nama)
print(nim)
print(ttl)
print(jenis_kelamin)
print(hobi)
